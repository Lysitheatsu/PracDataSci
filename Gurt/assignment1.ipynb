# %% [markdown]
# # Task 1: Data Preparation

# %%
# Start from here to write your code for Task 1. Please also feel free to add more cells in this ipynb file. 
import pandas as pd
import numpy as np
import re

#1 Loads the original CSV into a dataframe.
df = pd.read_csv("victorian_road_crash_data.csv")

# %%
#Fixes the date and time columns to be in the correct format for easier analysis.
df['ACCIDENT_DATE'] = pd.to_datetime(df['ACCIDENT_DATE'], format='%d/%m/%Y', errors='coerce')
df['ACCIDENT_TIME'] = pd.to_datetime(df['ACCIDENT_TIME'], format='%H:%M:%S', errors='coerce').dt.time

# %%
#Fixing some of the missing data
# Will drop the SRNS column as it is missing a good portion of data
df = df.drop(columns=['SRNS']) 

#dropping rows with missing values in the specified columns as it is a small portion of data and not really needed if we have suburb
df = df.dropna(subset=['LATITUDE', 'LONGITUDE', 'NO_OF_VEHICLES', ])

#will fill the missing values with a unknown for caterogical data 
categorical_cols = ['ROAD_NAME', 'ROAD_TYPE', 'LGA_NAME', 'DTP_REGION', 
                    'DEG_URBAN_NAME', 'RMA', 'DIVIDED', 'STAT_DIV_NAME']
df[categorical_cols] = df[categorical_cols].fillna('Unknown')

# %%
#drops the non needed vicgrid due to having lat x long
df = df.drop(columns=['VICGRID_X', 'VICGRID_Y'], errors='ignore')

# we need to keep the lat and long so itll filted out junk ones
df = df.dropna(subset=['LATITUDE', 'LONGITUDE'])

# %%
#4 Cleans the Speed_Zone column
def clean_speed(val):
    if pd.isna(val):
        return np.nan
    val = str(val).lower()


    if 'not know' in val or 'other' in val: 
        return np.nan
    

# Uses normal experessions to extract the number before being put back in the cleaned 
    nums = re.findall(r'\d+', val)
    if nums:
        speed = int(nums[0])
     #Cleans anomalies like 10000 km/hr
        if speed > 110 or speed == 0:
            return np.nan
        return speed
    return np.nan

# fixes the the values and not incuding .2 and what not 
df['SPEED_ZONE_NUM'] = df['SPEED_ZONE'].apply(clean_speed).astype('Int64')

# %%
# List of columns that should be whole numbers, not decimals.
cols_to_fix = [
    'NO_OF_VEHICLES', 'HEAVYVEHICLE', 'PASSENGERVEHICLE', 
    'MOTORCYCLE', 'PT_VEHICLE'
]

# Convert them to integers
for col in cols_to_fix:
    df[col] = df[col].astype(int)

# Optional: You might want to do this for ROAD_ROUTE_1 too if you filled its NaNs
df['ROAD_ROUTE_1'] = df['ROAD_ROUTE_1'].fillna(0).astype(int)

# %%
# Fixes the DEG_URBAN_NAME column to replace underscores with spaces for better readability.
df['DEG_URBAN_NAME'] = df['DEG_URBAN_NAME'].str.replace('_', ' ', regex=False)

# Fixes the vehicle count columns to be whole numbers (2.0 -> 2)
cols_to_fix = ['NO_OF_VEHICLES', 'HEAVYVEHICLE', 'PASSENGERVEHICLE', 'MOTORCYCLE', 'PT_VEHICLE']
for col in cols_to_fix:
    df[col] = df[col].astype(int)

# %%
# Create a new clean numerical column for speeds
df['SPEED_ZONE_NUM'] = df['SPEED_ZONE'].apply(clean_speed)

# 5. diplays that it processed correctely and then displays the first few rows allowing for user to verify the changes.
print(f"Data successfully cleaned. New shape: {df.shape}")
display(df.head())
# Out:
# Data successfully cleaned. New shape: (150395, 50)
#     ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME  \
# 0  T20150000784    2015-01-01      17:50:00
# 1  T20150000043    2015-01-01      19:30:00
# 2  T20150000037    2015-01-01      19:00:00
# 3  T20150000008    2015-01-01      00:10:00
# 4  T20150000050    2015-01-01      04:00:00
#
#                        ACCIDENT_TYPE DAY_OF_WEEK  DCA_CODE  \
# 0             Collision with vehicle    Thursday       163
# 1  No collision and no object struck    Thursday       184
# 2             Collision with vehicle    Thursday       110
# 3             Collision with vehicle    Thursday       120
# 4                  Struck Pedestrian    Thursday       109
#
#                                 DCA_CODE_DESCRIPTION        LIGHT_CONDITION  \
# 0  VEHICLE STRIKES DOOR OF PARKED/STATIONARY VEHICLE                    Day
# 1            OUT OF CONTROL ON CARRIAGEWAY (ON BEND)              Dusk/Dawn
# 2                  CROSS TRAFFIC(INTERSECTIONS ONLY)              Dusk/Dawn
# 3                           HEAD ON (NOT OVERTAKING)  Dark No street lights
# 4  ANY MANOEUVRE INVOLVING PED NOT INCLUDED IN DC...  Dark No street lights
#
#   POLICE_ATTEND        ROAD_GEOMETRY  ... NO_OF_VEHICLES HEAVYVEHICLE  \
# 0            No  Not at intersection  ...              2            0
# 1           Yes       T intersection  ...              1            0
# 2           Yes   Cross intersection  ...              2            0
# 3           Yes  Not at intersection  ...              2            0
# 4           Yes  Not at intersection  ...              1            0
#
#   PASSENGERVEHICLE MOTORCYCLE PT_VEHICLE  DEG_URBAN_NAME               RMA  \
# 0                1          0          0      MELB URBAN  Arterial Highway
# 1                0          1          0  RURAL VICTORIA    Arterial Other
# 2                1          0          0      MELB URBAN    Arterial Other
# 3                0          2          0  RURAL VICTORIA           Unknown
# 4                1          0          0  RURAL VICTORIA        Local Road
#
#      DIVIDED  STAT_DIV_NAME  SPEED_ZONE_NUM
# 0  Undivided          Metro            50.0
# 1  Undivided          Metro            60.0
# 2    Divided          Metro            60.0
# 3    Unknown        Country           100.0
# 4  Undivided        Country            50.0
#
# [5 rows x 50 columns]

# %%
df.to_csv('cleaned.csv', index=False)

# %% [markdown]
# # Task 2: Data Exploration

# %% [markdown]
# ## Task 2.1

# %%
# Code goes after this line by adding cells

# %% [markdown]
# ## Task 2.2

# %%
# Code goes after this line by adding cells

# %% [markdown]
# ## Task 2.3

# %%
# Code goes after this line by adding cells
